# %%
from datetime import datetime
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import re
from konlpy.tag import Mecab
mecab = Mecab()

#import lightgbm as lgb

import tensorflow as tf
import keras
# Out:
# Using TensorFlow backend.

# %%
pd.options.display.max_rows = 1000

# %%
df = pd.read_csv('./data/train.csv')

# %%
def parse_sentence(sentence):
    prev_word, prev_pos = '', ''
    nouns = []
    words = []
    etc = []
    buff = ''
    ret = []
    condition = False
    idx, condidx = 0, 0
    
    if sentence[:4] == '(광고)':
        words.append('(광고)')
        nouns.append('(광고)')
        sentence = sentence[4:]

    for word, pos in mecab.pos(sentence):

        if pos in ('SF') or pos[:1] in ('J'):
            # 은/는/이/가/. 등
            prev_word, prev_pos = '', ''
            continue

        if pos[:1] == 'N' and prev_pos[:1] == 'S':
            # 1억, 1천만원 등
            word = re.sub('[억천만]', '', word)
            if len(word) == 0:
                continue

        if pos[:1] == 'S':
            word = re.sub('[(:)]', '', word)
            word = re.sub('[0-9.X]+', 'X', word)

        # 조건절 판단
        if prev_pos[-3:] == 'ETM' and word in ['분','고객','개인','사업자','이','대상','당신','직원','VIP', '자','분도','전문직','신용자','외국인','본인','임직원','부모','회계사','귀하','투자자','분과']:
            condition = True  
        elif pos[:1] == 'N':
            if word[:2] in ('경우', '필요', '라면', '다면'): # 경우, 필요 단어 등장 시 조건절로 판단
                condition = True
        elif pos[-2:] == 'EC':
            # 여도, 라도, 라면, 면
            if word[-1:] in ('면', '도') or word[-2:] in ('도록'):
                condition = True

        if pos[:1] == 'E':
            buff += word
        #elif pos[:1] == 'N' and prev_pos[:1] == 'N' and len(word) == 1:
        #    buff += word
        elif pos[:1] == 'S' and prev_pos[:1] == 'S' and word[:1] in 'X0123456789%.-': #('%', '.', '-'):
            if buff[-1:] in ('시', '원', '%'):
                words.append(buff)
                buff = ''
            buff += word
            #buff += re.sub('[0-9.X]+', 'X', word)
            #buff = re.sub('[0-9.X]+', 'X', buff)
        elif pos[:1] == 'N' and prev_pos[:1] == 'S' and len(buff) > 0 and word in ('시', '분', '초', '시간'):
            buff = re.sub('시', '', buff)
            buff += '시'
        elif pos[:1] == 'N' and prev_pos[:1] == 'S' and len(buff) > 0 and word in ('년', '월', '일', '개월'):
            buff = re.sub('일', '', buff)
            buff += '일'
        elif pos[:1] == 'N' and prev_pos[:1] == 'S' and len(buff) > 0 and word in ('원'):
            buff = re.sub('원', '', buff)
            buff += '원'
        elif pos[:1] == 'N' and prev_pos[:1] == 'S' and len(buff) > 0 and word in ('건', '배', 'pt'):
            buff += word
        else:
            if len(buff) > 0:
                buff = re.sub('[0-9.X]+', 'X', buff)
                buff = re.sub('[-]+', '-', buff)
                buff = re.sub('[X]+', 'X', buff)
                if buff != 'X':
                    words.append(buff)
                    # M, N 경우만 저장해보자
                    if prev_pos[:1] in ('N'):  # 'M', 
                        nouns.append(buff)
            buff = word
            prev_word, prev_pos = word, pos

        if pos[-2:] in ('EF'): # and word[0][-1:] in ['요', '다']:
            # words가 꼭 명사를 뜻하는 게 아니고 특색있는 키워드 모두를 포함
            if len(buff) > 0:
                words.append(buff)
            buff = ''
            if condition:
                ret.append([word, condition, nouns])
            else:
                ret.append([word, condition, words])
            idx += 1
            if condition: condidx += 1
            nouns = []
            words = []
            condition = False
    if len(buff) > 0:
        words.append(buff)
    if len(words) > 0:
        if condition:
            ret.append([word, condition, nouns])
        else:
            ret.append([word, condition, words])
        #ret.append([word, condition, nouns])
        idx += 1
        if condition: condidx += 1
    etc.append(condidx / idx)
    return ret, etc

# %%
smishings = []
normals = []
idx = 0
for idx, item in df.iterrows():
    #print(item.text)
    splited, etc = parse_sentence(item.text)
    etc.append(np.log(len(item.text))/8)  # 문장 전체의 길이
    etc.append(np.log(len(splited))/4)  # 문장의 개수
    splited.append(etc)
    splited.append(item.id)
    #splited = m.parse(item.text).split()
    if item.smishing == 1:
        smishings.append(splited)
    else:
        normals.append(splited)
    if idx % 100000 == 0:
        print(datetime.now(), idx)
    idx += 1
#     if idx > 20000:
#         break
# Out:
# 2020-01-05 09:02:23.724615 0
# 2020-01-05 09:03:27.552884 100000
# 2020-01-05 09:04:51.194701 200000

# %%
[print(x) for x in smishings[3]]
# Out:
# ['세요', False, ['(광고)', '안녕', '하세요']]
# ['습니다', True, ['수신', '희망', '경우', '거부', '답장', '수신', '거부', '목록', '등록', '번', '발송', '조치']]
# ['습니다', False, ['추가', '자금', '이나', '채무', '통합', '상담', '안내', '문자', '발송', '하였습니다']]
# ['깁니다', True, ['담당', '팀장', '줄', 'X시', '시간', '저', '글', '끝', '조금', '도움', '거', '판단', '글']]
# ['입니다', False, ['일전', '금융', '상담', '해', '드렸던', '입니다']]
# ['습니다', False, ['이런', '연락', '들', '하루', '몇', '번', '씩', '받으실', '텐데', '저', '거들게', '되어', '깊은', '사과', '말씀', '드리겠습니다']]
# ['습니다', False, ['다름', '아니라', '이번', '대출', '전문', '컨설팅', '회사', '이직', '했습니다']]
# ['습니다', False, ['기존', '금융', '근무', '할', '때', '세렉', '트론', '한', '상품', '취급', '했지만', '이제', '전', '금융', '권', '전부', '가이드', '해', '드릴', '수', '있기', '때문', '보다', '나은', '금융', '서비스', '제공', '해', '드릴', '수', '있습니다']]
# ['합니다', False, ['고객', '님', '이용', '중', '이신', '금융', '권', '중', '금리', '높은', '부분', '추후', '저금리', '추가', '자금', '채무', '통합', '기존', '정부', '상품', '햇살', '론', '새', '희망', '드림', '론', '정부', '지원', '자금', '사', '잇돌', '보증', '재단', '상품', '담보', '아파트', '빌라', '상가', '건물', '토지', '등', '상품', '차량', '상품', '또한', '진행', '가능', '합니다']]
# ['습니다', True, ['사항', '언제', '연락', '성심', '상담']]
# ['십니다', True, ['마지막', '부채', '부채', '통합', '걱정', '부채', '고객', '부채', 'X원', '상태', '등급', '한도', '최대']]
# ['십니다', True, ['상황', '진행', '부채', '통합', '상품', '부채', '진행', '가능']]
# ['입니다', False, ['부채', '통합', '상품', '오히려', '부채', '많으신', '분', '들', '이용', '하시는', '상품', '입니다']]
# ['습니다', True, ['위', '내용', '중', '하나', '해당', '분', '들', '언제', '전화', '문자', '연락', '정확', '상담']]
# ['습니다', True, ['셈', '연락', '만족', '수', '최선', '신뢰', '수', '상담', '도움']]
# ['습니다', True, ['불편', '발신', '번호', '무료', '수신', '거부', '문자', '수신', '거부', '처리']]
# ['은행', False, ['불편', '하게', '해', '드', '정말', '광고', '은행']]
# [0.47058823529411764, 0.8553354102798028, 0.708303336014054]
# 45
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
class wordCounter():
    def __init__(self):
        self.word_bank = {}
    
    def add_bucket(self, bucket_name):
        self.word_bank[bucket_name] = {}
        
    def add_list(self, bucket_name, word_list:[]):
        bucket = self.word_bank[bucket_name]
        for keyword in word_list:
            if keyword in bucket:
                bucket[keyword] += 1
            else:
                bucket[keyword] = 1
                
    def get_counts(self, bucket_name):
        return self.word_bank[bucket_name]

# %%
wc = wordCounter()
wc.add_bucket('conditioned')
wc.add_bucket('general')

for normal in normals:
    for item in normal[:-2]:
        if item[1] == True:
            wc.add_list('conditioned', item[2])
        else:
            wc.add_list('general', item[2])

for smishing in smishings:
    for item in smishing[:-2]:
        if item[1] == True:
            wc.add_list('conditioned', item[2])
        else:
            wc.add_list('general', item[2])

# %%
conditioned_df = pd.Series(wc.get_counts('conditioned'))
general_df = pd.Series(wc.get_counts('general'))

# 글자가 2개 이상인 것만 모아보자
conditioned_df = conditioned_df[conditioned_df.index.map(len) > 1]  # M,N 만 포함시켰으므로.. 길이 2이상인것만
#general_df = general_df[general_df.index.map(len) > 1]

# 3번 이상 출현한 것만 모아보자
#conditioned_df = conditioned_df[conditioned_df.sort_values() > 2]
#general_df = general_df[general_df.sort_values() > 2]

# %%
general_dic = general_df[general_df > 1].sort_values(ascending=False)
general_dic = general_dic.reset_index()['index'].to_dict()
general_vocab = {general_dic.get(k):k for k in general_dic}

# %%
conditioned_dic = conditioned_df[conditioned_df > 1].sort_values(ascending=False)
conditioned_dic = conditioned_dic.reset_index()['index'].to_dict()
conditioned_vocab = {conditioned_dic.get(k):k for k in conditioned_dic}

# %%
# smishing cases; length of vocab when it's out of vocab
tidf_conditioned = []
tidf_general = []
tidf_etc = []

cond_vocabsize = len(conditioned_vocab)
gen_vocabsize = len(general_vocab)

print('size of vocab (conditioned, general):', cond_vocabsize, gen_vocabsize)
for msg in normals:
    tidf_conditioned.append([conditioned_vocab.get(x) if x in conditioned_vocab else cond_vocabsize for row in msg[:-2] if row[1] == True for x in row[2]])
#     tidf_general.append([general_vocab.get(x) if x in general_vocab else gen_vocabsize for row in msg[:-2] if row[1] == False for x in row[2]])
    tidf_general.append([general_vocab.get(x) if x in general_vocab else gen_vocabsize for row in msg[:-2] for x in row[2]])    
    tidf_etc.append(msg[-2])
for msg in smishings:
    tidf_conditioned.append([conditioned_vocab.get(x) if x in conditioned_vocab else cond_vocabsize for row in msg[:-2] if row[1] == True for x in row[2]])
#     tidf_general.append([general_vocab.get(x) if x in general_vocab else gen_vocabsize for row in msg[:-2] if row[1] == False for x in row[2]])
    tidf_general.append([general_vocab.get(x) if x in general_vocab else gen_vocabsize for row in msg[:-2] for x in row[2]])
    tidf_etc.append(msg[-2])
# Out:
# size of vocab (conditioned, general): 9070 32667

# %%
len(tidf_conditioned), len(tidf_general), len(tidf_etc)
# Out:
# (295945, 295945, 295945)

# %%
convec_size = max(max([len(x) for x in tidf_conditioned]), max([len(x) for x in tidf_conditioned]))
genvec_size = max(max([len(x) for x in tidf_general]), max([len(x) for x in tidf_general]))

# 문장 내 인식한 단어의 개수의 최대값 (문장의 길이가 길수록 크겠지..)
print('conditioned vector minimum size:', convec_size)
print('general vector minimum size:', genvec_size)
# Out:
# conditioned vector minimum size: 258
# general vector minimum size: 388

# %%
# 훈련용, 훈련검증용, 결과검증용 분리
tidf_conditioned = np.array(tidf_conditioned)
tidf_general = np.array(tidf_general)
tidf_etc = np.array(tidf_etc)
tidf_label = np.array([1 if x >= len(normals) else 0 for x in range(tidf_conditioned.shape[0])])

# %%
train_size = 70
num_batch = int(np.ceil(train_size / 32))
num_batch
# Out:
# 3

# %%
np.array(range(train_size)) // 32 == 2
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True,  True,  True,  True,  True,  True])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

class DataGenerator(keras.utils.Sequence):
    def __init__(self, tidf_cond_train, tidf_gen_train, tidf_etc_train, tidf_label_train, normal_size=160, smishing_size=160, convec_size=350, genvec_size=470):
        self.convec_size = convec_size  # including 0 paddings
        self.genvec_size = genvec_size  # including 0 paddings
        self.tidf_cond_train_normal = pad_sequences(tidf_cond_train[tidf_label_train == 0], maxlen=self.convec_size, padding='pre')
        self.tidf_gen_train_normal = pad_sequences(tidf_gen_train[tidf_label_train == 0], maxlen=self.genvec_size, padding='pre')
        self.tidf_etc_train_normal = tidf_etc_train[tidf_label_train == 0]
        self.tidf_cond_train_smishing = pad_sequences(tidf_cond_train[tidf_label_train == 1], maxlen=self.convec_size, padding='pre')
        self.tidf_gen_train_smishing = pad_sequences(tidf_gen_train[tidf_label_train == 1], maxlen=self.genvec_size, padding='pre')
        self.tidf_etc_train_smishing = tidf_etc_train[tidf_label_train == 1]
        self.sample_size_normal = normal_size
        self.sample_size_smishing = smishing_size
        self.train_size_normal = len(self.tidf_cond_train_normal)
        self.train_size_smishing = len(self.tidf_cond_train_smishing)
#         self.sample_size = normal_size + smishing_size
#         self.num_batch = int(np.ceil(len(self.tidf_cond_train_normal) // self.sample_size / 10))
        self.num_batch_normal = int(np.ceil(self.train_size_normal / self.sample_size_normal))
        self.num_batch_smishing = int(np.ceil(self.train_size_smishing / self.sample_size_smishing))
        self.normal_train_index = np.array(range(self.train_size_normal))
        self.smishing_train_index = np.array(range(self.train_size_smishing))
        print(f"num_batch_normal: {self.num_batch_normal}, num_batch_smishing: {self.num_batch_smishing}")
    
    def __len__(self):
        return max(self.num_batch_normal, self.num_batch_smishing)
    
    def __getitem__(self, index):
        # sequencial sampling
        normal_idx, smishing_idx = index % self.num_batch_normal, index % self.num_batch_smishing
        #print(f"normal_idx: {normal_idx}, smishing_idx: {smishing_idx}")
        normal_sampling = self.normal_train_index // self.sample_size_normal == normal_idx
#         normal_sampling = np.random.choice(len(self.tidf_cond_train_normal), self.normal_sample_size)
        normal_cond_sample = self.tidf_cond_train_normal[normal_sampling]
        normal_gen_sample = self.tidf_gen_train_normal[normal_sampling]
        normal_etc_sample = self.tidf_etc_train_normal[normal_sampling]
        smishing_sampling = self.smishing_train_index // self.sample_size_smishing == smishing_idx
#         smishing_sampling = np.random.choice(len(self.tidf_cond_train_smishing), self.smishing_sample_size)
        smishing_cond_sample = self.tidf_cond_train_smishing[smishing_sampling]
        smishing_gen_sample = self.tidf_gen_train_smishing[smishing_sampling]
        smishing_etc_sample = self.tidf_etc_train_smishing[smishing_sampling]
        sample_cond_train = np.concatenate([normal_cond_sample, smishing_cond_sample])
        sample_gen_train = np.concatenate([normal_gen_sample, smishing_gen_sample])
        sample_etc_train = np.concatenate([normal_etc_sample, smishing_etc_sample])
        sample_label_train = [1 if x >= len(normal_cond_sample) else 0 for x in range(len(sample_cond_train))]
        return [sample_cond_train, sample_gen_train, sample_etc_train], sample_label_train
#        return [sample_gen_train, sample_etc_train], sample_label_train

    def on_epoch_end(self):
        pass

# %%
TRAIN_RATIO, VALID_RATIO = 0.6, 0.8
np.random.seed(0)
split = np.random.rand(tidf_conditioned.shape[0])
tidf_cond_train = tidf_conditioned[split < TRAIN_RATIO]
tidf_cond_valid = tidf_conditioned[(split >= TRAIN_RATIO) & (split < VALID_RATIO)]
tidf_cond_test = tidf_conditioned[split >= VALID_RATIO]

tidf_gen_train = tidf_general[split < TRAIN_RATIO]
tidf_gen_valid = tidf_general[(split >= TRAIN_RATIO) & (split < VALID_RATIO)]
tidf_gen_test = tidf_general[split >= VALID_RATIO]

tidf_etc_train = tidf_etc[split < TRAIN_RATIO]
tidf_etc_valid = tidf_etc[(split >= TRAIN_RATIO) & (split < VALID_RATIO)]
tidf_etc_test = tidf_etc[split >= VALID_RATIO]

tidf_label_train = tidf_label[split < TRAIN_RATIO]
tidf_label_valid = tidf_label[(split >= TRAIN_RATIO) & (split < VALID_RATIO)]
tidf_label_test = tidf_label[split >= VALID_RATIO]

tidf_cond_train.shape, tidf_cond_valid.shape #, tidf_cond_test.shape
# Out:
# ((177533,), (59281,))

# %%
num_predictive_factors1, num_predictive_factors2 = 24, 32
n_cond, n_gen, n_etc = convec_size, genvec_size, len(tidf_etc_train[0])
cond_input = keras.layers.Input(shape=(n_cond,), name='Cond')
gen_input = keras.layers.Input(shape=(n_gen,), name='General')
etc_input = keras.layers.Input(shape=(n_etc,), name='Etc')

cond_vec_mlp = keras.layers.Embedding(cond_vocabsize + 1, num_predictive_factors1, )(cond_input)
cond_vec_mlp = keras.layers.Flatten(name='Flattenconds-MLP')(cond_vec_mlp)
cond_vec_mlp = keras.layers.Dropout(0.3)(cond_vec_mlp)

# cond_dense = keras.layers.Dense(32, kernel_regularizer=keras.regularizers.l1(0.001), name='FullyConnected-Cond')(cond_vec_mlp)
# cond_dropout = keras.layers.Dropout(0.3, name='Dropout-Cond')(cond_dense)

gen_vec_mlp = keras.layers.Embedding(gen_vocabsize + 1, num_predictive_factors2, )(gen_input)
gen_vec_mlp = keras.layers.Flatten(name='Flattengens-MLP')(gen_vec_mlp)
gen_vec_mlp = keras.layers.Dropout(0.3)(gen_vec_mlp)

# gen_dense = keras.layers.Dense(32, kernel_regularizer=keras.regularizers.l1(0.001), name='FullyConnected-Gen')(gen_vec_mlp)
# gen_dropout = keras.layers.Dropout(0.3, name='Dropout-Gen')(gen_dense)

concat_mlp = keras.layers.merge.concatenate([cond_vec_mlp, gen_vec_mlp, etc_input]) # , etc_input
concat_dropout_mlp = keras.layers.Dropout(0.3)(concat_mlp)

dense = keras.layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001), name='FullyConnected-1', activation='relu')(concat_dropout_mlp)
dropout_1 = keras.layers.Dropout(0.3, name='Dropout-1')(dense)

#dense_2 = keras.layers.Dense(DENSE2, kernel_regularizer=keras.regularizers.l2(0.001), name='FullyConnected-2', activation='relu')(dropout_1)
#dropout_2 = keras.layers.Dropout(0.3, name='Dropout-2')(dense_2)

#dense_3 = keras.layers.Dense(DENSE3, kernel_regularizer=keras.regularizers.l2(0.001), name='FullyConnected-3', activation='relu')(dropout_2)
#dropout_3 = keras.layers.Dropout(0.3, name='Dropout-3')(dense_3)

dense_4 = keras.layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001), name='FullyConnected-4', activation='relu')(dropout_1)
pred_mlp = keras.layers.Dense(1, activation='sigmoid', name='Activation')(dense_4)

model = keras.Model(inputs=[cond_input, gen_input, etc_input ], output=pred_mlp)  #  etc_input
model.compile(optimizer=keras.optimizers.Adam(lr=1e-4), loss='binary_crossentropy', metrics=['binary_crossentropy', 'accuracy'])
#model.compile(optimizer=keras.optimizers.Adamax(lr=1e-3), loss='binary_crossentropy', metrics=['binary_crossentropy', 'accuracy'])
# Out:
# /home/xikizima/.conda/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("Ac...)`

# %%
train_gen = DataGenerator(tidf_cond_train, tidf_gen_train, tidf_etc_train, tidf_label_train, 160, 160, convec_size, genvec_size)
valid_gen = DataGenerator(tidf_cond_valid, tidf_gen_valid, tidf_etc_valid, tidf_label_valid, 1000, 1000, convec_size, genvec_size)

history = model.fit_generator(generator=train_gen,
                             epochs = 100,
#                              use_multiprocessing=True,
#                               workers=3,
                             validation_data=valid_gen,
                             verbose=1)
# Out:
# num_batch_normal: 1039, smishing_train_index: 71
# num_batch_normal: 56, smishing_train_index: 4
# Epoch 1/100
# 1039/1039 [==============================] - 199s 192ms/step - loss: 0.0047 - binary_crossentropy: 0.0014 - acc: 0.9998 - val_loss: 0.0092 - val_binary_crossentropy: 0.0062 - val_acc: 0.9985
# Epoch 2/100
# 1039/1039 [==============================] - 190s 183ms/step - loss: 0.0042 - binary_crossentropy: 0.0013 - acc: 0.9998 - val_loss: 0.0079 - val_binary_crossentropy: 0.0051 - val_acc: 0.9987
# Epoch 3/100
# 1039/1039 [==============================] - 190s 183ms/step - loss: 0.0039 - binary_crossentropy: 0.0012 - acc: 0.9998 - val_loss: 0.0065 - val_binary_crossentropy: 0.0039 - val_acc: 0.9989
# Epoch 4/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0035 - binary_crossentropy: 0.0010 - acc: 0.9998 - val_loss: 0.0075 - val_binary_crossentropy: 0.0050 - val_acc: 0.9987
# Epoch 5/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0032 - binary_crossentropy: 9.3351e-04 - acc: 0.9999 - val_loss: 0.0078 - val_binary_crossentropy: 0.0056 - val_acc: 0.9987
# Epoch 6/100
# 1039/1039 [==============================] - 186s 179ms/step - loss: 0.0031 - binary_crossentropy: 9.1418e-04 - acc: 0.9999 - val_loss: 0.0063 - val_binary_crossentropy: 0.0042 - val_acc: 0.9989
# Epoch 7/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0028 - binary_crossentropy: 7.9628e-04 - acc: 0.9999 - val_loss: 0.0072 - val_binary_crossentropy: 0.0053 - val_acc: 0.9987
# Epoch 8/100
# 1039/1039 [==============================] - 188s 181ms/step - loss: 0.0026 - binary_crossentropy: 7.7302e-04 - acc: 0.9999 - val_loss: 0.0067 - val_binary_crossentropy: 0.0049 - val_acc: 0.9987
# Epoch 9/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0025 - binary_crossentropy: 6.9429e-04 - acc: 0.9999 - val_loss: 0.0068 - val_binary_crossentropy: 0.0049 - val_acc: 0.9987
# Epoch 10/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0023 - binary_crossentropy: 6.3657e-04 - acc: 0.9999 - val_loss: 0.0054 - val_binary_crossentropy: 0.0038 - val_acc: 0.9989
# Epoch 11/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0022 - binary_crossentropy: 6.0525e-04 - acc: 0.9999 - val_loss: 0.0072 - val_binary_crossentropy: 0.0058 - val_acc: 0.9987
# Epoch 12/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0021 - binary_crossentropy: 6.1516e-04 - acc: 0.9999 - val_loss: 0.0084 - val_binary_crossentropy: 0.0067 - val_acc: 0.9987
# Epoch 13/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0021 - binary_crossentropy: 5.6874e-04 - acc: 0.9999 - val_loss: 0.0084 - val_binary_crossentropy: 0.0068 - val_acc: 0.9987
# Epoch 14/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0019 - binary_crossentropy: 4.9365e-04 - acc: 0.9999 - val_loss: 0.0068 - val_binary_crossentropy: 0.0055 - val_acc: 0.9987
# Epoch 15/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0019 - binary_crossentropy: 5.0328e-04 - acc: 0.9999 - val_loss: 0.0073 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 16/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0018 - binary_crossentropy: 4.5722e-04 - acc: 0.9999 - val_loss: 0.0073 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 17/100
# 1039/1039 [==============================] - 186s 179ms/step - loss: 0.0016 - binary_crossentropy: 4.1976e-04 - acc: 0.9999 - val_loss: 0.0066 - val_binary_crossentropy: 0.0054 - val_acc: 0.9987
# Epoch 18/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0016 - binary_crossentropy: 4.2582e-04 - acc: 0.9999 - val_loss: 0.0072 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 19/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0015 - binary_crossentropy: 3.7721e-04 - acc: 0.9999 - val_loss: 0.0066 - val_binary_crossentropy: 0.0055 - val_acc: 0.9987
# Epoch 20/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0015 - binary_crossentropy: 3.7239e-04 - acc: 0.9999 - val_loss: 0.0070 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 21/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0015 - binary_crossentropy: 3.8099e-04 - acc: 0.9999 - val_loss: 0.0067 - val_binary_crossentropy: 0.0057 - val_acc: 0.9988
# Epoch 22/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0014 - binary_crossentropy: 3.2416e-04 - acc: 0.9999 - val_loss: 0.0061 - val_binary_crossentropy: 0.0051 - val_acc: 0.9987
# Epoch 23/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0014 - binary_crossentropy: 3.3526e-04 - acc: 0.9999 - val_loss: 0.0071 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 24/100
# 1039/1039 [==============================] - 207s 199ms/step - loss: 0.0013 - binary_crossentropy: 2.8898e-04 - acc: 0.9999 - val_loss: 0.0075 - val_binary_crossentropy: 0.0065 - val_acc: 0.9987
# Epoch 25/100
# 1039/1039 [==============================] - 200s 193ms/step - loss: 0.0013 - binary_crossentropy: 3.0801e-04 - acc: 0.9999 - val_loss: 0.0074 - val_binary_crossentropy: 0.0063 - val_acc: 0.9987
# Epoch 26/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0013 - binary_crossentropy: 2.8021e-04 - acc: 0.9999 - val_loss: 0.0071 - val_binary_crossentropy: 0.0062 - val_acc: 0.9987
# Epoch 27/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0012 - binary_crossentropy: 2.8333e-04 - acc: 0.9999 - val_loss: 0.0073 - val_binary_crossentropy: 0.0064 - val_acc: 0.9987
# Epoch 28/100
# 1039/1039 [==============================] - 186s 179ms/step - loss: 0.0012 - binary_crossentropy: 2.6092e-04 - acc: 0.9999 - val_loss: 0.0063 - val_binary_crossentropy: 0.0055 - val_acc: 0.9988
# Epoch 29/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0012 - binary_crossentropy: 2.3207e-04 - acc: 1.0000 - val_loss: 0.0056 - val_binary_crossentropy: 0.0048 - val_acc: 0.9988
# Epoch 30/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0012 - binary_crossentropy: 2.5676e-04 - acc: 0.9999 - val_loss: 0.0078 - val_binary_crossentropy: 0.0068 - val_acc: 0.9987
# Epoch 31/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0011 - binary_crossentropy: 2.3903e-04 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0057 - val_acc: 0.9987
# Epoch 32/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0011 - binary_crossentropy: 2.2149e-04 - acc: 0.9999 - val_loss: 0.0059 - val_binary_crossentropy: 0.0051 - val_acc: 0.9988
# Epoch 33/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0011 - binary_crossentropy: 2.3862e-04 - acc: 0.9999 - val_loss: 0.0078 - val_binary_crossentropy: 0.0069 - val_acc: 0.9987
# Epoch 34/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 9.8904e-04 - binary_crossentropy: 2.0286e-04 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 35/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 0.0010 - binary_crossentropy: 2.0961e-04 - acc: 1.0000 - val_loss: 0.0063 - val_binary_crossentropy: 0.0052 - val_acc: 0.9987
# Epoch 36/100
# 1039/1039 [==============================] - 186s 179ms/step - loss: 9.7499e-04 - binary_crossentropy: 1.8281e-04 - acc: 1.0000 - val_loss: 0.0073 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 37/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 9.5043e-04 - binary_crossentropy: 1.9254e-04 - acc: 1.0000 - val_loss: 0.0072 - val_binary_crossentropy: 0.0064 - val_acc: 0.9987
# Epoch 38/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 9.9992e-04 - binary_crossentropy: 1.9014e-04 - acc: 1.0000 - val_loss: 0.0069 - val_binary_crossentropy: 0.0062 - val_acc: 0.9987
# Epoch 39/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 8.9496e-04 - binary_crossentropy: 1.7553e-04 - acc: 1.0000 - val_loss: 0.0061 - val_binary_crossentropy: 0.0054 - val_acc: 0.9988
# Epoch 40/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 9.5052e-04 - binary_crossentropy: 1.8656e-04 - acc: 1.0000 - val_loss: 0.0061 - val_binary_crossentropy: 0.0054 - val_acc: 0.9988
# Epoch 41/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 8.9092e-04 - binary_crossentropy: 1.7851e-04 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 42/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 8.9510e-04 - binary_crossentropy: 1.7709e-04 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 43/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 9.4585e-04 - binary_crossentropy: 1.6984e-04 - acc: 1.0000 - val_loss: 0.0059 - val_binary_crossentropy: 0.0052 - val_acc: 0.9988
# Epoch 44/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 8.5724e-04 - binary_crossentropy: 1.5867e-04 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0062 - val_acc: 0.9987
# Epoch 45/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 8.4569e-04 - binary_crossentropy: 1.6774e-04 - acc: 1.0000 - val_loss: 0.0072 - val_binary_crossentropy: 0.0063 - val_acc: 0.9988
# Epoch 46/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 8.6612e-04 - binary_crossentropy: 1.6081e-04 - acc: 1.0000 - val_loss: 0.0064 - val_binary_crossentropy: 0.0057 - val_acc: 0.9987
# Epoch 47/100
# 1039/1039 [==============================] - 186s 179ms/step - loss: 7.8083e-04 - binary_crossentropy: 1.4607e-04 - acc: 1.0000 - val_loss: 0.0062 - val_binary_crossentropy: 0.0056 - val_acc: 0.9988
# Epoch 48/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 8.4365e-04 - binary_crossentropy: 1.5570e-04 - acc: 1.0000 - val_loss: 0.0066 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 49/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.3674e-04 - binary_crossentropy: 1.4273e-04 - acc: 1.0000 - val_loss: 0.0069 - val_binary_crossentropy: 0.0063 - val_acc: 0.9987
# Epoch 50/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.9348e-04 - binary_crossentropy: 1.4485e-04 - acc: 1.0000 - val_loss: 0.0062 - val_binary_crossentropy: 0.0057 - val_acc: 0.9987
# Epoch 51/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.1322e-04 - binary_crossentropy: 1.2653e-04 - acc: 1.0000 - val_loss: 0.0059 - val_binary_crossentropy: 0.0054 - val_acc: 0.9988
# Epoch 52/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.6134e-04 - binary_crossentropy: 1.3334e-04 - acc: 1.0000 - val_loss: 0.0067 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 53/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.6479e-04 - binary_crossentropy: 1.4094e-04 - acc: 1.0000 - val_loss: 0.0072 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 54/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.5462e-04 - binary_crossentropy: 1.2928e-04 - acc: 1.0000 - val_loss: 0.0058 - val_binary_crossentropy: 0.0052 - val_acc: 0.9988
# Epoch 55/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.4955e-04 - binary_crossentropy: 1.3167e-04 - acc: 1.0000 - val_loss: 0.0062 - val_binary_crossentropy: 0.0056 - val_acc: 0.9987
# Epoch 56/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.6174e-04 - binary_crossentropy: 1.2135e-04 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0059 - val_acc: 0.9987
# Epoch 57/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.5639e-04 - binary_crossentropy: 1.2293e-04 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0063 - val_acc: 0.9988
# Epoch 58/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.1693e-04 - binary_crossentropy: 1.1865e-04 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0059 - val_acc: 0.9988
# Epoch 59/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.9996e-04 - binary_crossentropy: 1.1838e-04 - acc: 1.0000 - val_loss: 0.0066 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 60/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.8305e-04 - binary_crossentropy: 1.1606e-04 - acc: 1.0000 - val_loss: 0.0059 - val_binary_crossentropy: 0.0054 - val_acc: 0.9988
# Epoch 61/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.5801e-04 - binary_crossentropy: 1.1993e-04 - acc: 1.0000 - val_loss: 0.0061 - val_binary_crossentropy: 0.0056 - val_acc: 0.9988
# Epoch 62/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.1037e-04 - binary_crossentropy: 1.1329e-04 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0065 - val_acc: 0.9987
# Epoch 63/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.4526e-04 - binary_crossentropy: 1.0641e-04 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0064 - val_acc: 0.9987
# Epoch 64/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.6578e-04 - binary_crossentropy: 1.1166e-04 - acc: 1.0000 - val_loss: 0.0061 - val_binary_crossentropy: 0.0054 - val_acc: 0.9988
# Epoch 65/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.0667e-04 - binary_crossentropy: 1.0462e-04 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 66/100
# 1039/1039 [==============================] - 187s 180ms/step - loss: 6.3205e-04 - binary_crossentropy: 9.6317e-05 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 67/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.0367e-04 - binary_crossentropy: 9.8268e-05 - acc: 1.0000 - val_loss: 0.0067 - val_binary_crossentropy: 0.0063 - val_acc: 0.9987
# Epoch 68/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.8052e-04 - binary_crossentropy: 1.0553e-04 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 69/100
# 1039/1039 [==============================] - 191s 184ms/step - loss: 5.7302e-04 - binary_crossentropy: 1.0652e-04 - acc: 1.0000 - val_loss: 0.0083 - val_binary_crossentropy: 0.0076 - val_acc: 0.9987
# Epoch 70/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 7.7432e-04 - binary_crossentropy: 1.2196e-04 - acc: 1.0000 - val_loss: 0.0073 - val_binary_crossentropy: 0.0068 - val_acc: 0.9987
# Epoch 71/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.5377e-04 - binary_crossentropy: 9.2013e-05 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0064 - val_acc: 0.9987
# Epoch 72/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.3975e-04 - binary_crossentropy: 9.4693e-05 - acc: 1.0000 - val_loss: 0.0067 - val_binary_crossentropy: 0.0063 - val_acc: 0.9988
# Epoch 73/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.8002e-04 - binary_crossentropy: 9.7703e-05 - acc: 1.0000 - val_loss: 0.0071 - val_binary_crossentropy: 0.0067 - val_acc: 0.9987
# Epoch 74/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.9539e-04 - binary_crossentropy: 1.0049e-04 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 75/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.8063e-04 - binary_crossentropy: 1.0466e-04 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 76/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.2373e-04 - binary_crossentropy: 8.2240e-05 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 77/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.9126e-04 - binary_crossentropy: 9.8968e-05 - acc: 1.0000 - val_loss: 0.0067 - val_binary_crossentropy: 0.0063 - val_acc: 0.9987
# Epoch 78/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.0389e-04 - binary_crossentropy: 8.5550e-05 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0060 - val_acc: 0.9987
# Epoch 79/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.2663e-04 - binary_crossentropy: 8.6361e-05 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 80/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.3736e-04 - binary_crossentropy: 8.3942e-05 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0064 - val_acc: 0.9987
# Epoch 81/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.2003e-04 - binary_crossentropy: 8.3580e-05 - acc: 1.0000 - val_loss: 0.0072 - val_binary_crossentropy: 0.0068 - val_acc: 0.9988
# Epoch 82/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.6581e-04 - binary_crossentropy: 9.5876e-05 - acc: 1.0000 - val_loss: 0.0092 - val_binary_crossentropy: 0.0087 - val_acc: 0.9987
# Epoch 83/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.7998e-04 - binary_crossentropy: 8.0614e-05 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0064 - val_acc: 0.9987
# Epoch 84/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.7131e-04 - binary_crossentropy: 7.3407e-05 - acc: 1.0000 - val_loss: 0.0071 - val_binary_crossentropy: 0.0067 - val_acc: 0.9987
# Epoch 85/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.5866e-04 - binary_crossentropy: 8.1627e-05 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0059 - val_acc: 0.9988
# Epoch 86/100
# 1039/1039 [==============================] - 185s 179ms/step - loss: 5.4115e-04 - binary_crossentropy: 8.5051e-05 - acc: 1.0000 - val_loss: 0.0070 - val_binary_crossentropy: 0.0065 - val_acc: 0.9987
# Epoch 87/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.2208e-04 - binary_crossentropy: 9.1172e-05 - acc: 1.0000 - val_loss: 0.0084 - val_binary_crossentropy: 0.0076 - val_acc: 0.9988
# Epoch 88/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.3247e-04 - binary_crossentropy: 7.1805e-05 - acc: 1.0000 - val_loss: 0.0065 - val_binary_crossentropy: 0.0059 - val_acc: 0.9989
# Epoch 89/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.1882e-04 - binary_crossentropy: 7.7776e-05 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0065 - val_acc: 0.9987
# Epoch 90/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.0974e-04 - binary_crossentropy: 7.8753e-05 - acc: 1.0000 - val_loss: 0.0064 - val_binary_crossentropy: 0.0061 - val_acc: 0.9987
# Epoch 91/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.2157e-04 - binary_crossentropy: 7.6905e-05 - acc: 1.0000 - val_loss: 0.0072 - val_binary_crossentropy: 0.0068 - val_acc: 0.9987
# Epoch 92/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.7827e-04 - binary_crossentropy: 8.3478e-05 - acc: 1.0000 - val_loss: 0.0067 - val_binary_crossentropy: 0.0063 - val_acc: 0.9987
# Epoch 93/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.8732e-04 - binary_crossentropy: 7.1048e-05 - acc: 1.0000 - val_loss: 0.0068 - val_binary_crossentropy: 0.0064 - val_acc: 0.9988
# Epoch 94/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.2795e-04 - binary_crossentropy: 6.4863e-05 - acc: 1.0000 - val_loss: 0.0066 - val_binary_crossentropy: 0.0063 - val_acc: 0.9987
# Epoch 95/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 6.0913e-04 - binary_crossentropy: 8.6004e-05 - acc: 1.0000 - val_loss: 0.0067 - val_binary_crossentropy: 0.0062 - val_acc: 0.9987
# Epoch 96/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.8750e-04 - binary_crossentropy: 7.2760e-05 - acc: 1.0000 - val_loss: 0.0071 - val_binary_crossentropy: 0.0067 - val_acc: 0.9987
# Epoch 97/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 5.7415e-04 - binary_crossentropy: 7.9782e-05 - acc: 1.0000 - val_loss: 0.0071 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 98/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.2638e-04 - binary_crossentropy: 6.4865e-05 - acc: 1.0000 - val_loss: 0.0067 - val_binary_crossentropy: 0.0063 - val_acc: 0.9988
# Epoch 99/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.9879e-04 - binary_crossentropy: 7.0206e-05 - acc: 1.0000 - val_loss: 0.0069 - val_binary_crossentropy: 0.0066 - val_acc: 0.9987
# Epoch 100/100
# 1039/1039 [==============================] - 185s 178ms/step - loss: 4.6899e-04 - binary_crossentropy: 7.3059e-05 - acc: 1.0000 - val_loss: 0.0073 - val_binary_crossentropy: 0.0069 - val_acc: 0.9987

# %%
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots()
fig.set_figheight(10)
fig.set_figwidth(20)
acc_ax = loss_ax.twinx()
loss_ax.plot(history.history['loss'], 'y', label='train_loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val_loss')

acc_ax.plot(history.history['acc'], 'b', label='train_acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val_acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
data_gen_train = pad_sequences(tidf_gen_train, maxlen=genvec_size, padding='pre')
data_cond_train = pad_sequences(tidf_cond_train, maxlen=convec_size, padding='pre')
data_gen_valid = pad_sequences(tidf_gen_valid, maxlen=genvec_size, padding='pre')
data_cond_valid = pad_sequences(tidf_cond_valid, maxlen=convec_size, padding='pre')

# %%
*_, train_acc = model.evaluate([data_cond_train, data_gen_train], tidf_label_train)
*_, valid_acc = model.evaluate([data_cond_valid, data_gen_valid], tidf_label_valid)
train_acc, valid_acc, '{:.3f}%'.format(valid_acc / train_acc * 100)

# %%
data_gen_test = pad_sequences(tidf_gen_test, maxlen=genvec_size, padding='pre')
data_cond_test = pad_sequences(tidf_cond_test, maxlen=convec_size, padding='pre')
data_etc_test = tidf_etc_test

# %%
# 110 trained
pred_test = model.predict(x=[data_cond_test, data_gen_test, data_etc_test], batch_size=160)
gap = np.abs(tidf_label_test - pred_test.reshape([-1,]))

plt.figure(figsize=(20,10))
plt.plot(gap)

# %%
# 10 trained
pred_test = model.predict(x=[data_cond_test, data_gen_test, data_etc_test], batch_size=160)
gap = np.abs(tidf_label_test - pred_test.reshape([-1,]))

plt.figure(figsize=(20,10))
plt.plot(gap)

# %%
# test
pred_test = model.predict(x=[data_cond_test, data_gen_test, data_etc_test], batch_size=160)
gap = np.abs(tidf_label_test - pred_test.reshape([-1,]))

plt.figure(figsize=(20,10))
plt.plot(gap)

# %%
# 110 trained
from sklearn.metrics import confusion_matrix, roc_curve
from sklearn.metrics import auc
from matplotlib import pyplot as plt

fpr, tpr, thresholds = roc_curve(tidf_label_test, pred_test)
print('auc :', auc(fpr,tpr))

plt.figure(figsize=(5,5))
plt.plot(fpr,tpr,'-')
plt.plot([0,1],[0,1], 'k--')
plt.show()
# Out:
# auc : 0.9999985962241087

# %%
from sklearn.metrics import confusion_matrix, roc_curve
from sklearn.metrics import auc
from matplotlib import pyplot as plt

fpr, tpr, thresholds = roc_curve(tidf_label_test, pred_test)
print('auc :', auc(fpr,tpr))

plt.figure(figsize=(5,5))
plt.plot(fpr,tpr,'-')
plt.plot([0,1],[0,1], 'k--')
plt.show()
# Out:
# auc : 0.9999997685001162

# %%
# 제출 준비

# %%
submit_df = pd.read_csv('./data/public_test.csv')

# %%
unknowns = []

idx = 0
for idx, item in submit_df.iterrows():
    splited, etc = parse_sentence(item.text)
    etc.append(np.log(len(item.text))/8)  # 문장 전체의 길이
    etc.append(np.log(len(splited))/4)  # 문장의 개수
    splited.append(etc)
    splited.append(item.id)
    unknowns.append(splited)
    if idx % 100000 == 0:
        print(datetime.now(), idx)
    idx += 1
# Out:
# 2020-01-05 15:15:00.797099 0

# %%
# smishing cases; length of vocab when it's out of vocab
submit_conditioned = []
submit_general = []
submit_etc = []

cond_vocabsize = len(conditioned_vocab)
gen_vocabsize = len(general_vocab)

print('size of vocab (conditioned, general):', cond_vocabsize, gen_vocabsize)
for msg in unknowns:
    submit_conditioned.append([conditioned_vocab.get(x) if x in conditioned_vocab else cond_vocabsize for row in msg[:-2] if row[1] == True for x in row[2]])
#    submit_general.append([general_vocab.get(x) if x in general_vocab else gen_vocabsize for row in msg[:-2] if row[1] == False for x in row[2]])
    submit_general.append([general_vocab.get(x) if x in general_vocab else gen_vocabsize for row in msg[:-2] for x in row[2]])
    submit_etc.append(msg[-2])
# Out:
# size of vocab (conditioned, general): 9070 32667

# %%
data_submit_conditioned = pad_sequences(submit_conditioned, maxlen=convec_size, padding='pre')
data_submit_general = pad_sequences(submit_general, maxlen=genvec_size, padding='pre')
data_submit_etc = np.array(submit_etc)

# %%
pred_y = model.predict(x=[data_submit_conditioned, data_submit_general, data_submit_etc], verbose=1)
# Out:
# 1626/1626 [==============================] - 0s 106us/step

# %%
pred_y[pred_y > 1.0] = 1.0

# %%
submit_df['smishing'] = np.abs(pred_y)

# %%
submit_df[['id', 'smishing']].to_csv('./data/submission_20200105_1.csv', index=False)

# %%
# 컨디션 문장의 경우.. 명사만 가지고 만들까?.. 의 컨셉
# 0.962889 기록 (2020.01.04 23:50)
